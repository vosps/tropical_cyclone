# %% [markdown]
# ### Figure 9: HighResMIP

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hrmip_rain = np.load('/user/home/al18709/work/CMIP6/HighResMIP/EC-Earth3p/historical/storm_rain.npy')[-28000:]
real = np.load('/user/home/al18709/work/dsrnngan_predictions/validation_real-opt.npy')[0][:,:,:,0]

hrmip_peak = np.max(hrmip_rain,axis=(1,2))
real_peak = np.max(real,axis=(1,2))

hrmip_mean = np.mean(hrmip_rain,axis=(1,2))
real_mean = np.mean(real,axis=(1,2))

# %%
print(hrmip_peak.shape)
# Out:
# (28000,)

# %%
# plt.hist(hrmip_peak.flatten())
sns.histplot(data=hrmip_peak.flatten(), stat="density", fill=True,color='Blue',element='step')
sns.histplot(data=real_peak.flatten(), stat="density", fill=True,color='#cdeac0',element='step')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.histplot(data=hrmip_mean.flatten(), stat="density", fill=True,color='Blue',element='step')
sns.histplot(data=real_mean.flatten(), stat="density", fill=True,color='#cdeac0',element='step')
# Out:
# <AxesSubplot:ylabel='Density'>
