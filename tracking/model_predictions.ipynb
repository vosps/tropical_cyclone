# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
fp = "/user/home/al18709/work/gan_predictions_20/validation_pred-opt_no_rain_test_run_1.npy"

predictions = np.load(fp)

fp = "/user/home/al18709/work/gan_predictions_20/validation_real-opt_no_rain_test_run_1.npy"

real = np.load(fp)

# %%
print(predictions.shape)
print(real.shape)
# Out:
# (15930, 100, 100, 20)
# (15930, 100, 100, 1)

# %%
i = 2000

plt.imshow(predictions[i,:,:,1])

# %%
plt.imshow(real[i,:,:])

# %%
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# /tmp/ipykernel_29786/2891322758.py in <module>
# ----> 1 plt.plot(np.sort(sns.histplot(real.flatten())),np.sort(predictions[:,:,:,0].flatten()))
#       2
#       3
#       4
#       5
#
# <__array_function__ internals> in sort(*args, **kwargs)
#
# /user/work/al18709/.conda/envs/aquatic/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sort(a, axis, kind, order)
#     989     else:
#     990         a = asanyarray(a).copy(order="K")
# --> 991     a.sort(axis=axis, kind=kind, order=order)
#     992     return a
#     993
#
# AxisError: axis -1 is out of bounds for array of dimension 0
# Error in callback <function flush_figures at 0x7f83599c7320> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
